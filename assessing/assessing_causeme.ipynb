# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
import sys
sys.path.append("..")
sys.path.append("../d2c/")
import numpy as np
from d2c.simulatedTimeSeries import SimulatedTimeSeries
from d2c.D2C import D2C
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

# %%
# assuming df is your dataframe, X are your features, y is your target
df = pd.read_csv('with_extra_descriptors.csv')  # replace with your data file

# df = df.loc[df['graph_id']<500]
X = df.drop(columns=['graph_id','edge_source','edge_dest', 'is_causal'])
y = df['is_causal']


# create a Logistic Regression classifier
classifier = RandomForestClassifier(n_estimators=100, n_jobs=-1)
classifier.fit(X, y)
# Out:
# RandomForestClassifier(n_jobs=-1)

# %%
data_df = np.loadtxt("linear-VAR_N-3_T-150_0001.txt")
data_df = pd.DataFrame(data_df)

# %%
d2c_test = D2C([None],[data_df])
X_test = d2c_test.compute_descriptors_no_dags()

# %%
pd.DataFrame(X_test)
# Out:
#    graph_id  edge_source  edge_dest         effca         effef    comcau  \
# 0         0            0          1 -5.295741e-17 -2.712446e-16  0.051925
# 1         0            0          2  1.466751e-16  6.100012e-17  0.260909
# 2         0            1          0  1.945942e-01 -5.295741e-17  0.048331
# 3         0            1          2 -1.125076e-16  4.950029e-17  0.029657
# 4         0            2          0  2.480726e-01  2.480726e-01  0.145937
# 5         0            2          1  4.950029e-17 -1.465698e-01  0.029452
#
#       delta        delta2      delta.i1      delta.i2  ...  B.kurtosis1  \
# 0  0.000000  0.000000e+00  0.000000e+00  0.000000e+00  ...    -0.550154
# 1  0.000000  0.000000e+00  0.000000e+00  0.000000e+00  ...    -0.550154
# 2  0.048331  0.000000e+00  5.628798e-08  5.628798e-08  ...    -0.328848
# 3  0.000000  0.000000e+00  0.000000e+00  0.000000e+00  ...    -0.328848
# 4  0.000000  6.447183e-07  0.000000e+00  0.000000e+00  ...    -0.026508
# ...

# %%
test_df = pd.DataFrame(X_test)
test_df = test_df.drop(['graph_id', 'edge_source', 'edge_dest'], axis=1)

# %%
y_test = classifier.predict(test_df)

# %%
y_test
# Out:
# array([0, 0, 1, 0, 1, 1], dtype=int64)
