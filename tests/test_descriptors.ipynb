# %%
#possibly to mock 
# rankrho, mRMR, normalized_conditional_information, coeff, ecdf, epred, HOC, and skew

# %%
import numpy as np
import pandas as pd
import pickle
import sys
sys.path.append("..")
sys.path.append("../d2c/")
# Generating random data for the test
np.random.seed(42)  # Seed for reproducibility
from utils import print_dag, dag_to_formula, show_dag

# %%
with open('../data/ts.pkl', 'rb') as f:
    observations, dags, updated_dags = pickle.load(f)

# %%
dag = dags[0]
observation = observations[0]
updated_dag = updated_dags[0]

# %%
print_dag(dag)
# Out:
# ####################
# Node 0 has attributes {'bias': 0, 'sigma': 0.001, 'seed': 42}
# Node 1 has attributes {'bias': 0, 'sigma': 0.001, 'seed': 42}
# Node 2 has attributes {'bias': 0, 'sigma': 0.001, 'seed': 42}
# Edge 0 -> 1 has attributes {'weight': -0.10584, 'H': 'linear'}
# Edge 0 -> 2 has attributes {'weight': -0.35387, 'H': 'linear'}

# %%
dag_to_formula(dag)
# Out:
# 0 = 0
# 1 = -0.10584*0 + 0
# 2 = -0.35387*0 + 0

# %%
show_dag(dag)

# %%
observations[4]
# Out:
#            0        1        2        0        2
# 0   -0.20403  0.89136  0.27233      NaN      NaN
# 1   -0.04730 -0.37526  0.13110 -0.00129 -0.00122
# 2   -0.02028  0.15864  0.06465  0.00047 -0.00003
# 3   -0.00648 -0.06716  0.02859  0.00089 -0.00089
# 4   -0.00384  0.02964  0.01425 -0.00094 -0.00167
# ..       ...      ...      ...      ...      ...
# 145 -0.00120 -0.00123  0.00032 -0.00063 -0.00013
# 146  0.00304 -0.00098 -0.00008 -0.00051 -0.00002
# 147 -0.00001  0.00053 -0.00115 -0.00027  0.00034
# 148  0.00025 -0.00074 -0.00152 -0.00032  0.00094
# 149 -0.00201 -0.00172 -0.00080 -0.00074  0.00094
#
# [150 rows x 5 columns]

# %%
import numpy as np
from pyitlib import discrete_random_variable as drv

# Sample data
A = np.random.randint(0, 2, 100)
B = np.random.randint(0, 2, 100)
C = np.random.randint(0, 2, 100)

# Compute conditional mutual information I(A; B | C)
cmi = drv.information_mutual_conditional(A, B, C)
print(cmi)
# Out:
# 0.02204948951117236

# %%
from d2c.D2C import D2C
d2c = D2C(dags,observations,n_jobs=10)
d2c.initialize()

# %%
def test_comcau_descriptor():
    # Setup
    mock_object = ...  # Instantiate object of the class
    mock_object.observations_from_DAGs = ...  # Set required attributes
    DAG_index = ...
    ca = ...
    ef = ...
    
    # Call the function
    result = mock_object._compute_descriptors(DAG_index, ca, ef)
    
    # Expected value - this should be known or precomputed
    expected_value = ...
    
    # Check if the result matches expected value
    assert np.isclose(result["comcau"], expected_value), f"Expected {expected_value}, but got {result["comcau"]}"
